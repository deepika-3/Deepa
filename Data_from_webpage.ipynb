# %% [markdown]
# <a href="https://colab.research.google.com/github/deepika-3/Deepa/blob/main/Data_from_webpage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: !pip install colab-xterm %load_ext colabxterm

# !pip install colab-xterm
# %load_ext colabxterm
# Out:
# Collecting colab-xterm
#   Downloading colab_xterm-0.2.0-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess~=0.7.0 in /usr/local/lib/python3.10/dist-packages (from colab-xterm) (0.7.0)
# Requirement already satisfied: tornado>5.1 in /usr/local/lib/python3.10/dist-packages (from colab-xterm) (6.3.2)
# Installing collected packages: colab-xterm
# Successfully installed colab-xterm-0.2.0

# %%
# !pip install beautifulsoup4
# !pip install numpy
# !pip install requests
# !pip install spacy
# !pip install trafilatura
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.4)
# Collecting trafilatura
#   Downloading trafilatura-1.7.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from trafilatura) (2023.11.17)
# Collecting courlan>=0.9.5 (from trafilatura)
#   Downloading courlan-0.9.5-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 4.8 MB/s eta 0:00:00
# Collecting htmldate>=1.7.0 (from trafilatura)
#   Downloading htmldate-1.7.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 4.3 MB/s eta 0:00:00
# Collecting justext>=3.0.0 (from trafilatura)
#   Downloading jusText-3.0.0-py2.py3-none-any.whl (837 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.8/837.8 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: lxml<6,>=4.9.4 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (4.9.4)
# Requirement already satisfied: charset-normalizer>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from trafilatura) (2.0.7)
# Requirement already satisfied: langcodes>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from courlan>=0.9.5->trafilatura) (3.3.0)
# Collecting tld>=0.13 (from courlan>=0.9.5->trafilatura)
#   Downloading tld-0.13-py2.py3-none-any.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.8/263.8 kB 14.0 MB/s eta 0:00:00
# Collecting dateparser>=1.1.2 (from htmldate>=1.7.0->trafilatura)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from htmldate>=1.7.0->trafilatura) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.7.0->trafilatura) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.7.0->trafilatura) (2023.6.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser>=1.1.2->htmldate>=1.7.0->trafilatura) (5.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->htmldate>=1.7.0->trafilatura) (1.16.0)
# Installing collected packages: tld, justext, dateparser, courlan, htmldate, trafilatura
# Successfully installed courlan-0.9.5 dateparser-1.2.0 htmldate-1.7.0 justext-3.0.0 tld-0.13 trafilatura-1.7.0

# %%
from bs4 import BeautifulSoup
import json
import numpy as np
import requests
from requests.models import MissingSchema
import spacy
import trafilatura

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote

def extract_text_from_url(url):
    try:
        # Properly format the URL
        formatted_url = quote(url, safe=':/')

        # Specify headers to send with the request
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept-Language': 'en-US,en;q=0.5',
            'Accept-Encoding': 'gzip, deflate, br',
            'Connection': 'keep-alive',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'
        }

        # Send a GET request to the URL with headers
        response = requests.get(formatted_url, headers=headers)

        # Check if the request was successful (status code 200)
        response.raise_for_status()

        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract text from the parsed HTML
        text = soup.get_text()

        return text
    except requests.exceptions.RequestException as e:
        print(f"Failed to retrieve content from {url}. Error: {e}")
        return None

# Example usage:
urls = ["https://blackcoffer.com"]
extracted_texts = {}

for url in urls:
    text = extract_text_from_url(url)
    extracted_texts[url] = text

# Print extracted text for each URL
for url, text in extracted_texts.items():
    print(f"Text extracted from {url}:")
    if text:
        print(text)
    else:
        print("Failed to retrieve text.")
    print("=" * 30)
# Out:
# Text extracted from https://blackcoffer.com:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Driving Digital Transformation: Blackcoffer's Expertise in IT Solutions and Application Development
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Monday - Saturday10 AM - 09 PM IST
#
# Visit our social pages
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Get a DemoContact Us
#
#
# Our Work
# Our Services
#
# Big Data & Analytics
# Application Development
# Consultancy
# Information Management
# HR & Staffing
#
#
# Industries
#
# Research and Academia
# Energy
# Healthcare
# Fast Moving Consumer Goods (FMCG)
# Banking Finance Service Insurance
# Supply Chain
# Organisations
# Business Planning
# Human Resources
#
#
# Products
#
# DataIntel
# DataOil
# Blackcoffer Insights
# SEO Tool
# Hirekingdom
# Workcroft
# BlackMarlin Style
# QNA
# BWStory
#
#
#
#
#
#
#
#
#
#
#
# WHAT'S MISSING IN YOUR BUSINESS?Find that
# Missing pieceLet us help you grow your business. At Blackcoffer, our fleet of experts is available to help you with any issues, and tailor the perfect solution for you!
# Our IndustriesOur ServicesCOMMITTED TO YOUR SUCCESSDelivering
# The promiseWith Blackcoffer's app development services, you can give leads the appropriate impression of your business without losing performance, speed, or results.Bigdata AnalyticsApplication DevelopmentWE WANT TO SEE YOU SUCCEEDYour success
# Our businessOur consulting services are tailored to address our clients' most pressing concerns and opportunities. Then we use our skills to solve those problems through data mining and research.
# ConsultancyResearch AcademiaPLAN, THEN DOOur ServicesAt Blackcoffer, we put our customers first. We create business value and achieve critical company objectives by providing innovative, best-in-class consulting and IT solutions.
#
# Blackcoffer servicesSMALL TACTICSOur ApproachWe take a pragmatic approach to creating new opportunities and solving complex problems. We are passionate about developing ideas, creating brilliant strategies for leading the digital revolution.
# More about BlackcofferPROOF, NOT PROMISESBlackcoffer SolutionsPartnering with you, we guide your business into the future. We create ground-breaking strategies that unlock new levels of growth. We take great pains to ensure your ambitions.
#
# Explore our SolutionsGROWING WITH OUR CLIENTS12 Years of
# Experience At Blackcoffer, we approach every case with an open mind. Our clients come first, and we invest the time and resources necessary to provide outstanding care. From our network of experts, our global team provides clients with powerful insights in varied fields from around the world.
# Here at Blackcoffer, we believe in compliance. We value it highly and we expect our people to take it seriously. Our culture is based on compliance, and our industry-leading standards are a cornerstone of that culture.
# Over the past 12 years of our experience, we’ve built ourselves to listen to your concerns and find the solution that’s best for your business now and well into the future.  We’ve helped hundreds of the world’s best companies.
# From Fortune 500 corporations, leading technology firms, professional services companies, to financial institutions. We connect them to the world’s largest source of first-hand expertise – anyone, anywhere in the world, with something important to share.
# ConsistencyOur regularity has always helped us grow and become the leading consulting companyImprovementWe are constantly enhancing our client's requirements by creating a better version.
# BranchingWe aim to work with more companies and grow to become the leading consulting agency.GREAT REVIEWS FOR OUR SERVICESTrusted by some
# Biggest Names Excellent Management!"Blackcoffer has provided excellent big data management expertise as a partner in ground breaking research and development. I look forward to continuing our work with great results and innovation."Dr. Terri McCormick DawsonCenter for leadership in GovernmentVery professional"Great consulting company and freelancing, very professional. Blackcoffer helps us with Data processing projects. Transform data from two sources, so that they match"Nejc ZnidarStatistician and financial modeler data researchGreat job solving"Blackcoffer’s team did a great job solving issues we were having in an iterative fashion and adapted well to changing technical approaches."
# Prof. Dr. Sebnem Kalemli-OzcanNeil Moskowitz Endowed Professor of Economics at University of MarylandBusiness PartnersAcademia PartnersREQUEST A CALL BACKGet your Business
# Right up There When you need intelligent answers to your toughest questions, we’re here to help. We’re just a call or email away! Don’t hang back from getting in touch with us. We’ll be glad to assist you.
# Request a Call Back012345678900123456789001234567890+Business advices given over 10 years
# 012345678900123456789001234567890+Businesses guided and solution delivered over 10 years
# 0123456789001234567890+Products delivered over 10 years
# Our TeamsFounder & CEOAjay BidyarthyHe has been key in growing analytics and technologies in Advertisement, Banking, Financials, Securities, & Insurance, Energy, Entertainment, Fast Moving Consumer Goods, Government & Think Tanks, Healthcare, IT Services, Lifestyle, eCommerce & Online Marketplace, Production & Manufacturing, Research & Academia, Retail & Supply Chain.Chief Operating Officer (COO)Uttam AnuragSpecialties: My area of specialization lies in leadership, project management, strategic planning, creative strategy, critical thinking, 3D visualization, 3D modeling, tender management, surveying, structural analysis, and construction drawings.He is instrumental in driving project management and leadership for businesses and shaping project execution planning.
# Chief Technology Officer (CTO)Mani VidyarthyHe is instrumental in driving technology and analytics for businesses and shaping decision support frameworks. He has gained expertise over the course of few years in Application Development, Social Media, SEO/SEM, Digital Strategy, Display Marketing & Remarketing, and Big Data Analytics, Branding, E-commerce, Mobile and App, Advertising, Campaigns.SEE WHAT WE DOConsultancy Cases
# ConsultancyRecommendation System Architecture
# ConsultancyHow do deep learning models predict old and new drugs that are successfully treated in healthcare?
# ConsultancyCentrality Measures & Their Meaning from the Network GraphsSee MoreOur ProductsGET SOLUTIONS FASTSearching for a First-Class Consultant?Get a DemoOUR OFFICESGet in TouchLet us know how we can assist you in growing your business, and we will provide you with one of the best services. Feel free to reach us.Address4/2, E-Extn, Shyam Vihar Phase 1, Najafgarh, Delhi - 110043, India
#
# Call us(+91) 7428477468
# (+356) 20106666Email ushello@blackcoffer.com
#
#
#
# BlackcofferHeadquartersBlackcoffer provide advanced analytic models of business processes to assist you in making optimal decisions.India, Phone: (+91) 74284 774684/2, E-Extn, Shyam Vihar Phase 1, Najafgarh, Delhi - 110043, Indiahello@blackcoffer.com INTERNATIONAL BRANCHESEurope38, St. James Street, Qawra, St. Paul's Bay, Malta, EuropeUSA1512 Anise Drive, Austin, TX 78741, USAKnow moreAbout us– About us
# – About Founder
# – Team
# – Our Process
# – Cost Calculator
# – Testimonials
# – Solutions
# – Careers
# – FAQ
# GET IN TOUCHBlackcoffer Social linksTaking seamless key performance indicators offline to maximise the long tail.BlackcofferHeadquartersBlackcoffer provide advanced analytic models of business processes to assist you in making optimal decisions.India, Phone: (+91) 74284 77468hello@blackcoffer.com3rd Floor, E - 512, Ramphal Square, Sector 7, Dwarka, New Delhi - 110075, IndiaOUR LOCATIONSWhere to find us?1512 Anise Drive, Austin, TX 78741, USA38, St. James Street, Qawra, St. Paul's Bay, Malta, EuropeGET IN TOUCHBlackcoffer Social linksTaking seamless key performance indicators offline to maximise the long tail.© All Rights Reserved, BLACKCOFFER (OPC) Pvt. Ltd.
# HOME
# OUR WORK
# OUR SERVICES
# SOLUTIONS
# BACK TO TOP
# © All Rights Reserved, BLACKCOFFER (OPC) Pvt. Ltd.
# HOME
# OUR WORK
# OUR SERVICES
# SOLUTIONS
# BACK TO TOP
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ==============================
