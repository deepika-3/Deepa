# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import pandas_datareader.data as web
from pandas import Series, DataFrame

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2017, 1, 11)

df = web.DataReader("AAPL", 'yahoo', start, end)
df.tail()

close_px = df['Adj Close']
mavg = close_px.rolling(window=100).mean()

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style

# Adjusting the size of matplotlib
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
mpl.__version__

# Adjusting the style of matplotlib
style.use('ggplot')

close_px.plot(label='AAPL')
mavg.plot(label='mavg')

df.shape
df.head(3)

import pandas as pd
import numpy as np

mcdonalds = pd.read_csv('mcdonalds.csv', usecols=range(1, 12))
mcdonalds.head()

mcdonalds.columns

mcdonalds.columns = [
    'calories', 'fat', 'sodium', 'carb', 'sugars', 'protein', 'calcium',
    'iron', 'vitamins', 'shelf', 'weight'
]

mcdonalds.head()

mcdonalds.dtypes

mcdonalds.info()

mcdonalds.describe()

mcdonalds.isnull().sum()

mcdonalds.isnull().sum().sum()

mcdonalds.isnull().any()

mcdonalds.isnull().any().any()

mcdonalds.isnull().any(axis=1)

mcdonalds.isnull().any(axis=1).any()

mcdonalds.isnull().any(axis=1).sum()

mcdonalds.
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA

from sklearn.preprocessing import StandardScaler



# load data

data = pd.read_csv('data.csv')

# data = data.drop(['Unnamed: 0'], axis=1)

# data = data.drop(['Unnamed: 0.1'], axis=1)

# data = data.drop(['Unnamed: 0.1.1'], axis=1)

# data = data.drop(['Unnamed: 0.1.1.1'], axis=1)

# data = data.drop(['Unnamed: 0.1.1.1.1'], axis=1)

# data = data.drop(['Unnamed: 0.1.1.1.1.1'], axis=1)

# data = data.drop(['Unnamed: 0.1.1.1.1.1.1'], axis=1)

import flexclust
import matplotlib.pyplot as plt
plt.scatter(predict(MD.pca), color='grey')
plt.show()


import random
random.seed(1234)
MD_km28 = stepFlexclust(MD_x, range(2, 8), nrep = 10, verbose = False)
MD_km28 = relabel(MD_km)

import matplotlib.pyplot as plt 

plt.plot(MD.km28)
plt.xlabel('number of segments')
plt.show()

np.random.seed(1234)
MD_b28 = bootFlexclust(MD_x, 2:8, nrep = 10, nboot = 100)

plt.plot(MD.b28, xlabel = "number of segments", ylabel = "adjusted Rand index")
plt.title("Plot of Adjusted Rand Index")
plt.show()

plt.hist(MD.km28['4'], bins = range(0,2), data = MD.x)
plt.xlim(0,1)

MD_k4 = MD_km28['4']

MD_r4 = slswFlexclust(MD_x, MD_k4)

import matplotlib.pyplot as plt

plt.plot(MD.r4)
plt.ylim(0,1)
plt.xlabel('segment number')
plt.ylabel('segment stability')
plt.show()

import flexmix
import numpy as np
np.random.seed(1234)
MD_m28 = flexmix.stepFlexmix(MD_x ~ 1, k = 2:8, nrep = 10, model = FLXMCmvbinary(), verbose = False)
print(MD_m28)

import matplotlib.pyplot as plt
plt.plot(MD.m28)
plt.ylabel('value of information criteria (AIC, BIC, ICL)')
plt.show()

clusters_m4 = clusters(MD.m4)
clusters_k4 = clusters(MD.k4)
table = pd.DataFrame({'mixture': clusters_m4, 'kmeans': clusters_k4})

import pandas as pd
MD_x = pd.DataFrame()
MD_k4 = pd.DataFrame()
MD_m4a = pd.cluster(MD_x - 1, cluster = MD_k4, model = FLXMCmvbinary())
pd.table(kmeans = clusters(MD_k4), mixture = clusters(MD_m4a))

print("log Lik. -7111.152 (df=47)")
print("log Lik. -7111.146 (df=47)")

rev = mcdonalds['Like'].tolist()[::-1]

mcdonalds['Like_n'] = 6 - mcdonalds['Like'].astype(int)
print(mcdonalds['Like_n'].value_counts())
f = 'Like.n ~ ' + ' + '.join(mcdonalds.keys()[1:11])

import numpy as np
np.random.seed(1234)
MD_reg2 = stepFlexmix(f, data = mcdonalds, k = 2, nrep = 10, verbose = False)

import flexmix
clustering = flexmix.FlexMix(f, data=mcdonalds, k=2, nrep=10, verbose=False)

import statsmodels.api as sm

MD_reg2 = sm.OLS(Y,X).fit()
MD_ref2 = MD_reg2.refit()
print(MD_ref2.summary())

MD_vclust = hclust(distance_matrix(MD_x.T))
import matplotlib.pyplot as plt 

plt.bar(MD.k4, MD.vclust$order, color = 'lightblue', align = 'center')
plt.xlabel('MD.k4')
plt.ylabel('MD.vclust$order')
plt.title('Barchart')
plt.show()

import matplotlib.pyplot as plt

plt.scatter(MD.x[:, 0], MD.x[:, 1], c=MD.k4, s=50, cmap='viridis')

plt.xlabel('principal component 1')
plt.ylabel('principal component 2')
plt.title('K-Means Clustering')

plt.colorbar();
import seaborn as sns
sns.mosaicplot(x="K4", y="Like", data=mcdonalds, shade=True, main=" ", xlabel='segment number')

import seaborn as sns
sns.mosaicplot(k4, data=mcdonalds, hue='Gender', shade=True)

import partykit

tree = partykit.ctree(factor(k4 == 3) ~ Like.n + Age + VisitFrequency + Gender, data = mcdonalds) 

partykit.plot(tree)

visit = mcdonalds['VisitFrequency'].astype(float).groupby(k4).mean()
like = mcdonalds.groupby('k4').mean()['Like.n']


female = mcdonalds.groupby('k4')['Gender'].apply(lambda x: (x == "Female").mean())
import matplotlib.pyplot as plt

visit = [3.5, 3.2, 3.0, 2.5]
like = [2.2, 1.9, 0.7, -1.2]
female = [0.8, 0.7, 0.6, 0.5]

plt.plot(visit, like, cex = [10 * val for val in female])
plt.xlim(2, 4.5)
plt.ylim(-3, 3)
for i, txt in enumerate(range(1,5)):
    plt.annotate(txt, (visit[i], like[i]))
plt.show()
